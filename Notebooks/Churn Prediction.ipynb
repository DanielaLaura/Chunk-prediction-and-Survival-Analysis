# %%
#import libraries necessary for this project
import numpy as np
import pandas as pd
from IPython.display import display # Allows the use of display() for DataFrames
import seaborn as sns
# Import supplementary visualizations code visuals.py
from vpython import *
# Pretty display for notebooks
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
test_1= pd.read_csv("tutorial_test1_data.csv")
labels= pd.read_csv("test1_labeled.csv")
app_train= pd.read_csv("tutorial_train_data.csv")

app_train.head(10)
# Out:
#    Unnamed: 0 actor_account_id  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  \
# 0           1         002CC4EC      24      193    39385         4    31160
# 1           2         003B1E06      19      176    37423         4    77029
# 2           3         003D42CD      26      102    33900         7  1797006
# 3           4         006093EB      34      237    49063         1        0
# 4           5         0067CFF2      10       28     4608         3        0
# 5           6         00731F6C       5       21     4881         1        0
# 6           7         007C7AEA      29      102    27108         8        0
# 7           8         007DA514      19       25     1352         2        0
# 8           9         008285F2      35      231    35585         4        0
# 9          10         00834BCF      26      451    28345         7    17916
#
#    exp_mastery_amt  exhaust_cnt  exhaust_pvp_cnt    ...     quest_cnt_cv  \
# ...

# %%
test_1.head()
# Out:
#    Unnamed: 0 actor_account_id  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  \
# 0           1         0002609C       3       39      953         1        0
# 1           2         0021D8AA      56      600   103168         9     7500
# 2           3         0034768E      22       76    15480         1        0
# 3           4         00513F5B      50      562    83244         3   109355
# 4           5         00679AED      28      408    46090         8        0
#
#    exp_mastery_amt  exhaust_cnt  exhaust_pvp_cnt      ...       \
# 0           232174            0                0      ...
# 1         28965882          404               40      ...
# 2          8139816            9                2      ...
# 3         23486486          274               21      ...
# 4         20697450           60                0      ...
#
#    die_pvp_cnt_cv  quest_cnt_cv  party_join_cnt_cv  party_kick_cnt_cv  \
# 0        2.236068      0.000000           0.000000                  0
# ...

# %%
test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 80 columns):
# Unnamed: 0                  3000 non-null int64
# actor_account_id            3000 non-null object
# dt_cnt                      3000 non-null int64
# con_cnt                     3000 non-null int64
# log_cnt                     3000 non-null int64
# char_cnt                    3000 non-null int64
# exp_amt                     3000 non-null int64
# exp_mastery_amt             3000 non-null int64
# exhaust_cnt                 3000 non-null int64
# exhaust_pvp_cnt             3000 non-null int64
# die_cnt                     3000 non-null int64
# die_pvp_cnt                 3000 non-null int64
# quest_cnt                   3000 non-null int64
# party_join_cnt              3000 non-null int64
# party_kick_cnt              3000 non-null int64
# guild_join_cnt              3000 non-null int64
# guild_withdraw_cnt          3000 non-null int64
# ...

# %%
app_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 81 columns):
# Unnamed: 0                  3999 non-null int64
# actor_account_id            3999 non-null object
# dt_cnt                      3999 non-null int64
# con_cnt                     3999 non-null int64
# log_cnt                     3999 non-null int64
# char_cnt                    3999 non-null int64
# exp_amt                     3999 non-null int64
# exp_mastery_amt             3999 non-null int64
# exhaust_cnt                 3999 non-null int64
# exhaust_pvp_cnt             3999 non-null int64
# die_cnt                     3999 non-null int64
# die_pvp_cnt                 3999 non-null int64
# quest_cnt                   3999 non-null int64
# party_join_cnt              3999 non-null int64
# party_kick_cnt              3999 non-null int64
# guild_join_cnt              3999 non-null int64
# guild_withdraw_cnt          3999 non-null int64
# ...

# %% [markdown]
# #### Integer Type

# %% [markdown]
# For each column, we'll count the number of unique values and show the result in a bar plot.

# %%
app_train.select_dtypes(np.int64).nunique().value_counts().sort_index().plot.bar(color='green', figsize=(6,4), 
                                                                           edgecolor = 'k', linewidth = 2);
plt.xlabel('Number of Unique Values'); plt.ylabel('Count');
plt.title('Count of Unique Values in Integer Columns');

# %% [markdown]
# The columns with only 2 unique values represent Booleans (0 or 1).

# %%
from collections import OrderedDict

plt.figure(figsize = (20, 16))
plt.style.use('fivethirtyeight')

#color mapping
colors = OrderedDict({0: 'green', 1: 'orange'})
churn_mapping=OrderedDict({0:'unchurned', 1:'churned'})
# Iterate through the float columns
for i,col in enumerate(train.select_dtypes('float')):
    ax = plt.subplot(5,5,i+1)
# Iterate through the poverty levels
    for churn, color in colors.items():
         # Plot each poverty level as a separate line
        sns.kdeplot(app_train.loc[app_train['churn_yn'] == churn, col].dropna(), 
                    ax = ax, color = color, label = churn_mapping[churn])
plt.title(f'{col.capitalize()} Distribution'); plt.xlabel(f'{col}'); plt.ylabel('Density')

plt.subplots_adjust(top = 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-f8eedb51bb4b> in <module>()
#       9 # Iterate through the float columns
#      10 for i,col in enumerate(train.select_dtypes('float')):
# ---> 11     ax = plt.subplot(5,5,i+1)
#      12 # Iterate through the poverty levels
#      13     for churn, color in colors.items():
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# ...

# %% [markdown]
# #### Exploring Label Distribution

# %%
app_train['churn_yn'].value_counts()

# %%
app_train['churn_yn'].astype(int).plot.hist()

# %% [markdown]
# ### Missing Values

# %%
#number of missing in each variable column
missing=pd.DataFrame(app_train.isnull().sum()).rename(columns={0:'total'})

#percentage of missing
missing['percentage']=missing['total']/len(app_train)
missing.sort_values('percentage', ascending=False).head(10)

# %%
import pandas as pd
import glob, os
 
os.chdir("D:/GMAE")
listCSV = glob.glob('*.csv')
results = pd.DataFrame([])
for counter, file in enumerate(listCSV):
    namedf = pd.read_csv(file, skiprows=0, usecols=[1,2,3])
    results = results.append(namedf)
 
results.to_csv('C:/combinedfile.csv')

# %%
test_1=test_1.merge(labels, on = 'actor_account_id', how = 'left')

# %%
train_labels = app_train['churn_yn']
#train = app_train.drop(columns = ['churn_yn']) 
train=app_train.drop(columns = ['actor_account_id'])
#test_1=test_1.drop(columns = ['actor_account_id'])

# %%
train.head()
# Out:
#    Unnamed: 0  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  exp_mastery_amt  \
# 0           1      24      193    39385         4    31160         10055435
# 1           2      19      176    37423         4    77029          4229266
# 2           3      26      102    33900         7  1797006         11180677
# 3           4      34      237    49063         1        0         12847058
# 4           5      10       28     4608         3        0          1801082
#
#    exhaust_cnt  exhaust_pvp_cnt  die_cnt    ...     quest_cnt_cv  \
# 0          162                4      145    ...         0.534082
# 1          171               37      114    ...         0.143501
# 2          141               48       84    ...         0.741191
# 3          177               30      109    ...         0.281266
# 4           31                5       27    ...         0.000000
#
#    party_join_cnt_cv  party_kick_cnt_cv  guild_join_cnt_cv  \
# ...

# %%
train = train.drop(columns = ['churn_yn'])

# %%
train.head()
# Out:
#    Unnamed: 0  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  exp_mastery_amt  \
# 0           1      24      193    39385         4    31160         10055435
# 1           2      19      176    37423         4    77029          4229266
# 2           3      26      102    33900         7  1797006         11180677
# 3           4      34      237    49063         1        0         12847058
# 4           5      10       28     4608         3        0          1801082
#
#    exhaust_cnt  exhaust_pvp_cnt  die_cnt      ...       die_pvp_cnt_cv  \
# 0          162                4      145      ...             1.007043
# 1          171               37      114      ...             1.414214
# 2          141               48       84      ...             2.137642
# 3          177               30      109      ...             2.236068
# 4           31                5       27      ...             0.000000
#
#    quest_cnt_cv  party_join_cnt_cv  party_kick_cnt_cv  guild_join_cnt_cv  \
# ...

# %%
test_1.head()
# Out:
#    Unnamed: 0 actor_account_id  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  \
# 0           1         0002609C       3       39      953         1        0
# 1           2         0021D8AA      56      600   103168         9     7500
# 2           3         0034768E      22       76    15480         1        0
# 3           4         00513F5B      50      562    83244         3   109355
# 4           5         00679AED      28      408    46090         8        0
#
#    exp_mastery_amt  exhaust_cnt  exhaust_pvp_cnt      ...        \
# 0           232174            0                0      ...
# 1         28965882          404               40      ...
# 2          8139816            9                2      ...
# 3         23486486          274               21      ...
# 4         20697450           60                0      ...
#
#    party_join_cnt_cv  party_kick_cnt_cv  guild_join_cnt_cv  \
# 0           0.000000                  0           0.000000
# ...

# %%
test_labels = test_1['churn_yn']
#train = app_train.drop(columns = ['churn_yn']) 
test_1=test_1.drop(columns = ['actor_account_id'])
test_1=test_1.drop(columns = ['churn_yn'])
test_1=test_1.drop(columns = ['survival_time'])
#test_1=test_1.drop(columns = ['actor_account_id'])

# %%
test_1.head()
# Out:
#    Unnamed: 0  dt_cnt  con_cnt  log_cnt  char_cnt  exp_amt  exp_mastery_amt  \
# 0           1       3       39      953         1        0           232174
# 1           2      56      600   103168         9     7500         28965882
# 2           3      22       76    15480         1        0          8139816
# 3           4      50      562    83244         3   109355         23486486
# 4           5      28      408    46090         8        0         20697450
#
#    exhaust_cnt  exhaust_pvp_cnt  die_cnt      ...       die_pvp_cnt_cv  \
# 0            0                0       25      ...             2.236068
# 1          404               40      972      ...             0.950096
# 2            9                2       22      ...             0.000000
# 3          274               21      569      ...             1.120342
# 4           60                0      309      ...             1.012131
#
#    quest_cnt_cv  party_join_cnt_cv  party_kick_cnt_cv  guild_join_cnt_cv  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Create the model with 100 trees
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
# Fit on training data
model.fit(train, train_labels)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
train_rf_predictions = model.predict(train)
train_rf_probs = model.predict_proba(train)[:, 1]

rf_predictions = model.predict(test_1)
rf_probs = model.predict_proba(test_1)[:, 1]

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, f1_score

# %%
def evaluate_model(predictions, probs, train_predictions, train_probs):
    """Compare machine learning model to baseline performance.
    Computes statistics and shows ROC curve."""
    
    baseline = {}
    
    baseline['recall'] = recall_score(test_labels, [1 for _ in range(len(test_labels))])
    baseline['precision'] = precision_score(test_labels, [1 for _ in range(len(test_labels))])
    baseline['roc'] = 0.5
    
    results = {}
    
    results['recall'] = recall_score(test_labels, predictions)
    results['precision'] = precision_score(test_labels, predictions)
    results['roc'] = roc_auc_score(test_labels, probs)
    
    train_results = {}
    train_results['recall'] = recall_score(train_labels, train_predictions)
    train_results['precision'] = precision_score(train_labels, train_predictions)
    train_results['roc'] = roc_auc_score(train_labels, train_probs)
    
    for metric in ['recall', 'precision', 'roc']:
        print(f'{metric.capitalize()} Baseline: {round(baseline[metric], 2)} Test: {round(results[metric], 2)} Train: {round(train_results[metric], 2)}')
    
    # Calculate false positive rates and true positive rates
    base_fpr, base_tpr, _ = roc_curve(test_labels, [1 for _ in range(len(test_labels))])
    model_fpr, model_tpr, _ = roc_curve(test_labels, probs)

    plt.figure(figsize = (8, 6))
    plt.rcParams['font.size'] = 16
    
    # Plot both curves
    plt.plot(base_fpr, base_tpr, 'b', label = 'baseline')
    plt.plot(model_fpr, model_tpr, 'r', label = 'model')
    plt.legend();
    plt.xlabel('False Positive Rate'); plt.ylabel('True Positive Rate'); plt.title('ROC Curves');

# %%
evaluate_model(rf_predictions, rf_probs, train_rf_predictions, train_rf_probs)
# Out:
# Recall Baseline: 1.0 Test: 0.9 Train: 1.0
# Precision Baseline: 0.3 Test: 0.32 Train: 1.0
# Roc Baseline: 0.5 Test: 0.66 Train: 1.0

# %%
from sklearn.model_selection import RandomizedSearchCV

# Hyperparameter grid
param_grid = {
    'n_estimators': np.linspace(10, 200).astype(int),
    'max_depth': [None] + list(np.linspace(3, 20).astype(int)),
    'max_features': ['auto', 'sqrt', None] + list(np.arange(0.5, 1, 0.1)),
    'max_leaf_nodes': [None] + list(np.linspace(10, 50, 500).astype(int)),
    'min_samples_split': [2, 5, 10],
    'bootstrap': [True, False]
}

# Estimator for use in random search
estimator = RandomForestClassifier(random_state = 42)

# Create the random search model
rs = RandomizedSearchCV(estimator, param_grid, n_jobs = -1, 
                        scoring = 'roc_auc', cv = 3, 
                        n_iter = 10, verbose = 1, random_state=42)

# Fit 
rs.fit(train, train_labels)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.1min finished
# RandomizedSearchCV(cv=3, error_score='raise',
#           estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=10, n_jobs=-1,
#           param_distributions={'n_estimators': array([ 10,  13,  17,  21,  25,  29,  33,  37,  41,  44,  48,  52,  56,
#         60,  64,  68,  72,  75,  79,  83,  87,  91,  95,  99, 103, 106,
#        110, 114, 118, 122, 126, 130, 134, 137, 141, 145, 149, 153, 157,
# ...

# %%
rs.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 14,
#  'max_features': 'auto',
#  'max_leaf_nodes': 31,
#  'min_samples_split': 2,
#  'n_estimators': 157}

# %%
best_model = rs.best_estimator_

# %%
train_rf_predictions = best_model.predict(train)
train_rf_probs = best_model.predict_proba(train)[:, 1]

rf_predictions = best_model.predict(test_1)
rf_probs = best_model.predict_proba(test_1)[:, 1]

# %%
n_nodes = []
max_depths = []

for ind_tree in best_model.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Average number of nodes 61
# Average maximum depth 9

# %%
evaluate_model(rf_predictions, rf_probs, train_rf_predictions, train_rf_probs)
# Out:
# Recall Baseline: 1.0 Test: 0.78 Train: 0.56
# Precision Baseline: 0.3 Test: 0.39 Train: 0.73
# Roc Baseline: 0.5 Test: 0.69 Train: 0.86

# %%
f1_score(test_labels, rf_predictions, average='binary')
# Out:
# 0.5203552923760177
